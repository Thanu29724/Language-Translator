# %%
### Open AI API Key and Open Source models--Llama3,Gemma2,mistral--Groq

import os
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_key=os.getenv("OPENAI_API_KEY")

groq_api_key=os.getenv("GROQ_API_KEY")
groq_api_key
# Out:
# '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'

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model=ChatGroq(model="openai/gpt-oss-120b",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000025323ED69E0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000025323ED5960>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage,SystemMessage
messages=[
    SystemMessage(content="Translate the following into from English to Kannada"),
    HumanMessage(content="my name is tanush m n")
]
result=model.invoke(messages)
result
# Out:
# AIMessage(content='ನನ್ನ ಹೆಸರು ತಾನುಷ್ ಎಮ್ ಎನ್.', additional_kwargs={'reasoning_content': 'The user asks: "Translate the following into from English to Kannada" and gives "my name is tan\n\nThe text: "my name is tanush m n". We need to translate to Kannada. Provide the translation. Likely "ನನ್ನ ಹೆಸರು ತಾನುಷ್ ಎಂ ಎನ್". In Kannada, "my name is ..." is "ನನ್ನ ಹೆಸರು ...". So "my name is tanush m n" => "ನನ್ನ ಹೆಸರು ತಾನುಷ್ ಎಮ್ ಎನ್". Should we preserve case? Probably not. Provide translation.'}, response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 89, 'total_tokens': 221, 'completion_time': 0.28651273, 'completion_tokens_details': {'reasoning_tokens': 111}, 'prompt_time': 0.003408217, 'prompt_tokens_details': None, 'queue_time': 0.046592293, 'total_time': 0.289920947}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_626f3fc5e0', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cebee-477b-70f1-
# ...

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'என் பெயர் தானுஷ் எம் என்.'

# %%
chain=model|parser
chain.invoke(messages)
# Out:
# 'ನನ್ನ ಹೆಸರು ತಾನುಷ್ ಎಂ ಎನ್.'

# %%
from langchain_core.prompts import ChatPromptTemplate
generic_template="Transalate the following into {language}:"
prompt=ChatPromptTemplate.from_messages(
    [("system",generic_template),('user',"{text}")]
)

# %%
prompt.invoke({"language":"French","text":"My name is adarsh"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Transalate the following into French:', additional_kwargs={}, response_metadata={}), HumanMessage(content='My name is adarsh', additional_kwargs={}, response_metadata={})])

# %%
print(result.content)
# Out:
# ನನ್ನ ಹೆಸರು ತಾನುಷ್ ಎಮ್ ಎನ್.

# %%
##Chaining together components with LCEL
chain=prompt|model|parser
chain.invoke({"language":"kannada","text":"MY name is THAnush M N"})
# Out:
# 'ನನ್ನ ಹೆಸರು ಥಾನುಷ್ ಎಮ್ ಎನ್.'
